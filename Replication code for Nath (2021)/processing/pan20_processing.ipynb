# %%
import os
import fnmatch
from random import shuffle
import json
from config import config_io,original_datasets, pan21_format,processed
from pathlib import Path
import json
import pandas as pd

# %%
import sys
sys.executable
# Out:
# '/home/sukanya/anaconda3/envs/tf-gpu/bin/python'

# %%
selected_dataset = 'train_2020_narrow'
data_path = pan21_format[selected_dataset]
print(data_path)
os.listdir(data_path)
base = [file.split(".")[0] for file in os.listdir(data_path) if "txt" in file]
truth_files = ["truth-"+file+".json" for file in base]
problem_files = [file+".txt" for file in base] 
#file_list = [data_path+'/'+file for file in temp_file_list]
# Out:
# /home/sukanya/PhD/CLEF/converted_data/2020/narrow/train

# %%
def verify_file_exists(file_list,data_path):
    for file in file_list:
        if not Path(data_path+"/"+file).exists():
            print("Error! Could not find file: ",data_path+file)

# %%
verify_file_exists(truth_files,data_path)
verify_file_exists(problem_files,data_path)

# %%
def convertPAN_to_siamese_format(text,truth_data, problem_file):
    a1_list = []
    a2_list = []
    p1_list = []
    p2_list = []
    p_list = []
    paragraph_authors = truth_data['paragraph-authors']
    paragraphs = text.split("\n\n")
    non_zero_len_paragraphs = [para for para in paragraphs if len(para)>0] # problem-601 creates an empty paragraph causing the problem. so had to remove empty paragraphs
    if len(non_zero_len_paragraphs)!= len(paragraph_authors):
        print(f"Error! Number of paragraphs {len(non_zero_len_paragraphs)} does not equal paragraph authors {len(paragraph_authors)}! God help you now!")
        print(paragraph_authors)
        for para in non_zero_len_paragraphs:
            print(f"\n len: {len(para)} {para}")
            return None, None, None, None, None
    else:
        for i in range(0, len(paragraph_authors)):
            a1 = paragraph_authors[i]
            if i+1<len(paragraph_authors) and (i+1)< len(paragraphs):
                a2 = paragraph_authors[i+1]
                p1 = non_zero_len_paragraphs[i]
                p2 = non_zero_len_paragraphs[i+1]
                a1_list.append(a1)
                p1_list.append(p1)
                a2_list.append(a2)
                p2_list.append(p2)
                p_list.append(problem_file)
    return p_list, a1_list, a2_list, p1_list, p2_list

# %%
def read_text_json(problem_path, truth_path):
    with open(problem_path) as f:
        text = f.read()
    print("len:", len(text))
    with open(truth_path) as json_file:
        data = json.load(json_file)
    return text, data

# %%
a1_list = []
a2_list = []
p1_list = []
p2_list = []
p_list = []

for i in range(0,len(truth_files)): #['truth-problem-1432.json'] 
    truth_file = truth_files[i]
    problem_file =   problem_files[i] #'problem-1432.txt'
    print((truth_file, problem_file))
    text, data = read_text_json(data_path+"/"+problem_file, data_path+"/"+truth_file)
    p_list_temp, a1_list_temp, a2_list_temp, p1_list_temp, p2_list_temp = convertPAN_to_siamese_format(text,data, problem_file)
    if p_list_temp and a1_list_temp and a2_list_temp and p1_list_temp and p2_list_temp:
        p_list.extend(p_list_temp)
        a1_list.extend(a1_list_temp)
        a2_list.extend(a2_list_temp)
        p1_list.extend(p1_list_temp)
        p2_list.extend(p2_list_temp)
data = {"problem":p_list, "author_1":a1_list, "author_2":a2_list, "para1_text": p1_list, "para2_text":p2_list}
print(len(p_list), len( a1_list),  len( a2_list),  len( p1_list), len( p2_list))
df = pd.DataFrame(data)
# Out:
# ('truth-problem-1543.json', 'problem-1543.txt')
# len: 11558
# ('truth-problem-631.json', 'problem-631.txt')
# len: 11507
# ('truth-problem-2471.json', 'problem-2471.txt')
# len: 10393
# ('truth-problem-2717.json', 'problem-2717.txt')
# len: 11661
# ('truth-problem-1839.json', 'problem-1839.txt')
# len: 13653
# ('truth-problem-1554.json', 'problem-1554.txt')
# len: 11139
# ('truth-problem-2399.json', 'problem-2399.txt')
# len: 19963
# ('truth-problem-2754.json', 'problem-2754.txt')
# len: 11548
# ('truth-problem-1068.json', 'problem-1068.txt')
# len: 10167
# ('truth-problem-3065.json', 'problem-3065.txt')
# len: 17054
# ('truth-problem-2836.json', 'problem-2836.txt')
# len: 19390
# ('truth-problem-2182.json', 'problem-2182.txt')
# len: 6937
# ('truth-problem-347.json', 'problem-347.txt')
# len: 8387
# ('truth-problem-378.json', 'problem-378.txt')
# len: 12347
# ('truth-problem-793.json', 'problem-793.txt')
# len: 7438
# ('truth-problem-2447.json', 'problem-2447.txt')
# len: 13814
# ('truth-problem-2091.json', 'problem-2091.txt')
# len: 8315
# ('truth-problem-3103.json', 'problem-3103.txt')
# len: 8229
# ('truth-problem-2116.json', 'problem-2116.txt')
# len: 6020
# ('truth-problem-287.json', 'problem-287.txt')
# len: 8951
# ('truth-problem-1973.json', 'problem-1973.txt')
# len: 10659
# ('truth-problem-771.json', 'problem-771.txt')
# len: 10057
# ('truth-problem-2812.json', 'problem-2812.txt')
# len: 14342
# ('truth-problem-2750.json', 'problem-2750.txt')
# len: 13868
# ('truth-problem-1156.json', 'problem-1156.txt')
# len: 8921
# ('truth-problem-719.json', 'problem-719.txt')
# len: 5407
# ('truth-problem-2916.json', 'problem-2916.txt')
# len: 9252
# ('truth-problem-2125.json', 'problem-2125.txt')
# len: 11397
# ('truth-problem-3412.json', 'problem-3412.txt')
# len: 12517
# ('truth-problem-1270.json', 'problem-1270.txt')
# len: 9830
# ('truth-problem-1257.json', 'problem-1257.txt')
# len: 14697
# ('truth-problem-3231.json', 'problem-3231.txt')
# len: 14156
# ('truth-problem-172.json', 'problem-172.txt')
# len: 13770
# ('truth-problem-2281.json', 'problem-2281.txt')
# len: 16022
# ('truth-problem-2418.json', 'problem-2418.txt')
# len: 10673
# ('truth-problem-3040.json', 'problem-3040.txt')
# len: 18993
# ('truth-problem-2167.json', 'problem-2167.txt')
# len: 12261
# ('truth-problem-899.json', 'problem-899.txt')
# len: 11613
# ('truth-problem-566.json', 'problem-566.txt')
# len: 7407
# ('truth-problem-2978.json', 'problem-2978.txt')
# len: 12701
# ('truth-problem-377.json', 'problem-377.txt')
# len: 14530
# ('truth-problem-2937.json', 'problem-2937.txt')
# len: 12453
# ('truth-problem-1325.json', 'problem-1325.txt')
# len: 6033
# ('truth-problem-2172.json', 'problem-2172.txt')
# len: 8046
# ('truth-problem-1534.json', 'problem-1534.txt')
# len: 17027
# ('truth-problem-1117.json', 'problem-1117.txt')
# len: 15442
# ('truth-problem-205.json', 'problem-205.txt')
# len: 13245
# ('truth-problem-3288.json', 'problem-3288.txt')
# len: 15771
# ('truth-problem-367.json', 'problem-367.txt')
# len: 16268
# ('truth-problem-2247.json', 'problem-2247.txt')
# len: 12344
# ('truth-problem-2092.json', 'problem-2092.txt')
# len: 15807
# ('truth-problem-2696.json', 'problem-2696.txt')
# len: 14209
# ('truth-problem-1494.json', 'problem-1494.txt')
# len: 12950
# ('truth-problem-2304.json', 'problem-2304.txt')
# len: 13262
# ('truth-problem-1013.json', 'problem-1013.txt')
# len: 13637
# ('truth-problem-1826.json', 'problem-1826.txt')
# len: 8404
# ('truth-problem-3281.json', 'problem-3281.txt')
# len: 7427
# ('truth-problem-2415.json', 'problem-2415.txt')
# len: 8161
# ('truth-problem-1338.json', 'problem-1338.txt')
# len: 15507
# ('truth-problem-1316.json', 'problem-1316.txt')
# len: 13071
# ('truth-problem-441.json', 'problem-441.txt')
# len: 12630
# ('truth-problem-1847.json', 'problem-1847.txt')
# len: 7041
# ('truth-problem-8.json', 'problem-8.txt')
# len: 14707
# ('truth-problem-117.json', 'problem-117.txt')
# len: 15038
# ('truth-problem-2861.json', 'problem-2861.txt')
# len: 16746
# ('truth-problem-826.json', 'problem-826.txt')
# len: 10535
# ('truth-problem-2895.json', 'problem-2895.txt')
# len: 11421
# ('truth-problem-101.json', 'problem-101.txt')
# len: 13966
# ('truth-problem-2178.json', 'problem-2178.txt')
# len: 15715
# ('truth-problem-1476.json', 'problem-1476.txt')
# len: 13849
# ('truth-problem-1150.json', 'problem-1150.txt')
# len: 9307
# ('truth-problem-2913.json', 'problem-2913.txt')
# len: 7888
# ('truth-problem-396.json', 'problem-396.txt')
# len: 8034
# ('truth-problem-3116.json', 'problem-3116.txt')
# len: 11394
# ('truth-problem-2761.json', 'problem-2761.txt')
# len: 8754
# ('truth-problem-1901.json', 'problem-1901.txt')
# len: 13248
# ('truth-problem-3210.json', 'problem-3210.txt')
# len: 12484
# ('truth-problem-2910.json', 'problem-2910.txt')
# len: 10116
# ('truth-problem-2999.json', 'problem-2999.txt')
# len: 20151
# ('truth-problem-1803.json', 'problem-1803.txt')
# len: 12847
# ('truth-problem-669.json', 'problem-669.txt')
# len: 8346
# ('truth-problem-803.json', 'problem-803.txt')
# len: 15279
# ('truth-problem-1240.json', 'problem-1240.txt')
# len: 7920
# ('truth-problem-2202.json', 'problem-2202.txt')
# len: 14462
# ('truth-problem-2381.json', 'problem-2381.txt')
# len: 10824
# ('truth-problem-3242.json', 'problem-3242.txt')
# len: 8336
# ('truth-problem-3108.json', 'problem-3108.txt')
# len: 8672
# ('truth-problem-627.json', 'problem-627.txt')
# len: 7554
# ('truth-problem-2782.json', 'problem-2782.txt')
# len: 13141
# ('truth-problem-1178.json', 'problem-1178.txt')
# len: 15576
# ('truth-problem-1860.json', 'problem-1860.txt')
# len: 7392
# ('truth-problem-1935.json', 'problem-1935.txt')
# len: 14733
# ('truth-problem-329.json', 'problem-329.txt')
# len: 11265
# ('truth-problem-518.json', 'problem-518.txt')
# len: 14661
# ('truth-problem-673.json', 'problem-673.txt')
# len: 15663
# ('truth-problem-1406.json', 'problem-1406.txt')
# len: 7281
# ('truth-problem-3376.json', 'problem-3376.txt')
# len: 7313
# ('truth-problem-3291.json', 'problem-3291.txt')
# len: 8036
# ('truth-problem-784.json', 'problem-784.txt')
# len: 13687
# ('truth-problem-484.json', 'problem-484.txt')
# len: 8044
# ('truth-problem-2954.json', 'problem-2954.txt')
# len: 15557
# ('truth-problem-1681.json', 'problem-1681.txt')
# len: 15940
# ('truth-problem-19.json', 'problem-19.txt')
# len: 16516
# ('truth-problem-3082.json', 'problem-3082.txt')
# len: 14658
# ('truth-problem-1638.json', 'problem-1638.txt')
# len: 17610
# ('truth-problem-2842.json', 'problem-2842.txt')
# len: 12110
# ('truth-problem-309.json', 'problem-309.txt')
# len: 10971
# ('truth-problem-2064.json', 'problem-2064.txt')
# len: 15745
# ('truth-problem-3188.json', 'problem-3188.txt')
# len: 9676
# ('truth-problem-1221.json', 'problem-1221.txt')
# len: 16230
# ('truth-problem-3331.json', 'problem-3331.txt')
# len: 14550
# ('truth-problem-2119.json', 'problem-2119.txt')
# len: 14148
# ('truth-problem-624.json', 'problem-624.txt')
# len: 9603
# ('truth-problem-2568.json', 'problem-2568.txt')
# len: 11483
# ('truth-problem-427.json', 'problem-427.txt')
# len: 12829
# ('truth-problem-2293.json', 'problem-2293.txt')
# len: 16257
# ('truth-problem-941.json', 'problem-941.txt')
# len: 10133
# ('truth-problem-974.json', 'problem-974.txt')
# len: 11267
# ('truth-problem-1029.json', 'problem-1029.txt')
# len: 13789
# ('truth-problem-81.json', 'problem-81.txt')
# len: 11184
# ('truth-problem-2848.json', 'problem-2848.txt')
# len: 7341
# ('truth-problem-1144.json', 'problem-1144.txt')
# len: 6678
# ('truth-problem-2448.json', 'problem-2448.txt')
# len: 12501
# ('truth-problem-1290.json', 'problem-1290.txt')
# len: 15792
# ('truth-problem-3363.json', 'problem-3363.txt')
# len: 11531
# ('truth-problem-313.json', 'problem-313.txt')
# len: 10422
# ('truth-problem-3189.json', 'problem-3189.txt')
# len: 11209
# ('truth-problem-150.json', 'problem-150.txt')
# len: 6885
# ('truth-problem-2355.json', 'problem-2355.txt')
# len: 9306
# ('truth-problem-570.json', 'problem-570.txt')
# len: 8300
# ('truth-problem-1109.json', 'problem-1109.txt')
# len: 12739
# ('truth-problem-1625.json', 'problem-1625.txt')
# len: 9152
# ('truth-problem-3023.json', 'problem-3023.txt')
# len: 17958
# ('truth-problem-982.json', 'problem-982.txt')
# len: 16886
# ('truth-problem-2181.json', 'problem-2181.txt')
# len: 16246
# ('truth-problem-1613.json', 'problem-1613.txt')
# len: 8966
# ('truth-problem-903.json', 'problem-903.txt')
# len: 6641
# ('truth-problem-3437.json', 'problem-3437.txt')
# len: 12158
# ('truth-problem-892.json', 'problem-892.txt')
# len: 8665
# ('truth-problem-2610.json', 'problem-2610.txt')
# len: 14877
# ('truth-problem-1809.json', 'problem-1809.txt')
# len: 10726
# ('truth-problem-2668.json', 'problem-2668.txt')
# len: 7687
# ('truth-problem-1422.json', 'problem-1422.txt')
# len: 13943
# ('truth-problem-89.json', 'problem-89.txt')
# len: 10118
# ('truth-problem-1001.json', 'problem-1001.txt')
# len: 15449
# ('truth-problem-944.json', 'problem-944.txt')
# len: 9301
# ('truth-problem-1113.json', 'problem-1113.txt')
# len: 7522
# ('truth-problem-3297.json', 'problem-3297.txt')
# len: 14543
# ('truth-problem-2026.json', 'problem-2026.txt')
# len: 11948
# ('truth-problem-917.json', 'problem-917.txt')
# len: 11490
# ('truth-problem-1659.json', 'problem-1659.txt')
# len: 5347
# ('truth-problem-778.json', 'problem-778.txt')
# len: 8608
# ('truth-problem-379.json', 'problem-379.txt')
# len: 11634
# ('truth-problem-3359.json', 'problem-3359.txt')
# len: 8148
# ('truth-problem-420.json', 'problem-420.txt')
# len: 11603
# ('truth-problem-2850.json', 'problem-2850.txt')
# len: 16536
# ('truth-problem-1688.json', 'problem-1688.txt')
# len: 10706
# ('truth-problem-2481.json', 'problem-2481.txt')
# len: 19948
# ('truth-problem-2312.json', 'problem-2312.txt')
# len: 14763
# ('truth-problem-1484.json', 'problem-1484.txt')
# len: 15287
# ('truth-problem-2763.json', 'problem-2763.txt')
# len: 12860
# ('truth-problem-3163.json', 'problem-3163.txt')
# len: 7190
# ('truth-problem-1523.json', 'problem-1523.txt')
# len: 8931
# ('truth-problem-776.json', 'problem-776.txt')
# len: 15354
# ('truth-problem-1262.json', 'problem-1262.txt')
# len: 10231
# ('truth-problem-2725.json', 'problem-2725.txt')
# len: 10519
# ('truth-problem-1323.json', 'problem-1323.txt')
# len: 15447
# ('truth-problem-1725.json', 'problem-1725.txt')
# len: 12269
# ('truth-problem-3084.json', 'problem-3084.txt')
# len: 17117
# ('truth-problem-1439.json', 'problem-1439.txt')
# len: 14814
# ('truth-problem-3133.json', 'problem-3133.txt')
# len: 12872
# ('truth-problem-2559.json', 'problem-2559.txt')
# len: 11271
# ('truth-problem-474.json', 'problem-474.txt')
# len: 6033
# ('truth-problem-927.json', 'problem-927.txt')
# len: 7616
# ('truth-problem-3095.json', 'problem-3095.txt')
# len: 11531
# ('truth-problem-2012.json', 'problem-2012.txt')
# len: 6907
# ('truth-problem-3321.json', 'problem-3321.txt')
# len: 11189
# ('truth-problem-1928.json', 'problem-1928.txt')
# len: 12603
# ('truth-problem-2260.json', 'problem-2260.txt')
# len: 8749
# ('truth-problem-2962.json', 'problem-2962.txt')
# len: 6124
# ('truth-problem-1216.json', 'problem-1216.txt')
# len: 9381
# ('truth-problem-438.json', 'problem-438.txt')
# len: 8558
# ('truth-problem-1516.json', 'problem-1516.txt')
# len: 15749
# ('truth-problem-1336.json', 'problem-1336.txt')
# len: 8876
# ('truth-problem-1078.json', 'problem-1078.txt')
# len: 8289
# ('truth-problem-2606.json', 'problem-2606.txt')
# len: 16853
# ('truth-problem-3187.json', 'problem-3187.txt')
# len: 16325
# ('truth-problem-2773.json', 'problem-2773.txt')
# len: 15068
# ('truth-problem-3045.json', 'problem-3045.txt')
# len: 11099
# ('truth-problem-562.json', 'problem-562.txt')
# len: 12695
# ('truth-problem-1021.json', 'problem-1021.txt')
# len: 15275
# ('truth-problem-841.json', 'problem-841.txt')
# len: 11081
# ('truth-problem-20.json', 'problem-20.txt')
# len: 11226
# ('truth-problem-1209.json', 'problem-1209.txt')
# len: 13480
# ('truth-problem-33.json', 'problem-33.txt')
# len: 13671
# ('truth-problem-3193.json', 'problem-3193.txt')
# len: 7159
# ('truth-problem-448.json', 'problem-448.txt')
# len: 16802
# ('truth-problem-1387.json', 'problem-1387.txt')
# len: 14460
# ('truth-problem-534.json', 'problem-534.txt')
# len: 11136
# ('truth-problem-2719.json', 'problem-2719.txt')
# len: 17473
# ('truth-problem-2534.json', 'problem-2534.txt')
# len: 11395
# ('truth-problem-268.json', 'problem-268.txt')
# len: 10183
# ('truth-problem-850.json', 'problem-850.txt')
# len: 13286
# ('truth-problem-1814.json', 'problem-1814.txt')
# len: 18711
# ('truth-problem-2924.json', 'problem-2924.txt')
# len: 9741
# ('truth-problem-2742.json', 'problem-2742.txt')
# len: 17588
# ('truth-problem-2051.json', 'problem-2051.txt')
# len: 7232
# ('truth-problem-1457.json', 'problem-1457.txt')
# len: 6259
# ('truth-problem-1020.json', 'problem-1020.txt')
# len: 15651
# ('truth-problem-1050.json', 'problem-1050.txt')
# len: 7041
# ('truth-problem-2994.json', 'problem-2994.txt')
# len: 15622
# ('truth-problem-1684.json', 'problem-1684.txt')
# len: 8505
# ('truth-problem-110.json', 'problem-110.txt')
# len: 11484
# ('truth-problem-3273.json', 'problem-3273.txt')
# len: 14238
# ('truth-problem-1304.json', 'problem-1304.txt')
# len: 9711
# ('truth-problem-788.json', 'problem-788.txt')
# len: 12274
# ('truth-problem-550.json', 'problem-550.txt')
# len: 13774
# ('truth-problem-1177.json', 'problem-1177.txt')
# len: 16178
# ('truth-problem-2729.json', 'problem-2729.txt')
# len: 16357
# ('truth-problem-1169.json', 'problem-1169.txt')
# len: 14429
# ('truth-problem-2612.json', 'problem-2612.txt')
# len: 15841
# ('truth-problem-1288.json', 'problem-1288.txt')
# len: 8613
# ('truth-problem-3343.json', 'problem-3343.txt')
# len: 9355
# ('truth-problem-713.json', 'problem-713.txt')
# len: 17369
# ('truth-problem-1312.json', 'problem-1312.txt')
# len: 12340
# ('truth-problem-558.json', 'problem-558.txt')
# len: 16682
# ('truth-problem-3230.json', 'problem-3230.txt')
# len: 7188
# ('truth-problem-756.json', 'problem-756.txt')
# len: 10507
# ('truth-problem-243.json', 'problem-243.txt')
# len: 14907
# ('truth-problem-1959.json', 'problem-1959.txt')
# len: 11673
# ('truth-problem-2892.json', 'problem-2892.txt')
# len: 10333
# ('truth-problem-2911.json', 'problem-2911.txt')
# len: 14368
# ('truth-problem-688.json', 'problem-688.txt')
# len: 15063
# ('truth-problem-2143.json', 'problem-2143.txt')
# len: 17149
# ('truth-problem-2437.json', 'problem-2437.txt')
# len: 9685
# ('truth-problem-2953.json', 'problem-2953.txt')
# len: 14524
# ('truth-problem-3429.json', 'problem-3429.txt')
# len: 11709
# ('truth-problem-851.json', 'problem-851.txt')
# len: 8218
# ('truth-problem-1241.json', 'problem-1241.txt')
# len: 12043
# ('truth-problem-2541.json', 'problem-2541.txt')
# len: 13703
# ('truth-problem-1417.json', 'problem-1417.txt')
# len: 7771
# ('truth-problem-3064.json', 'problem-3064.txt')
# len: 13622
# ('truth-problem-822.json', 'problem-822.txt')
# len: 12609
# ('truth-problem-2920.json', 'problem-2920.txt')
# len: 18034
# ('truth-problem-1444.json', 'problem-1444.txt')
# len: 7101
# ('truth-problem-190.json', 'problem-190.txt')
# len: 14444
# ('truth-problem-1995.json', 'problem-1995.txt')
# len: 7519
# ('truth-problem-2699.json', 'problem-2699.txt')
# len: 16167
# ('truth-problem-2560.json', 'problem-2560.txt')
# len: 13294
# ('truth-problem-1832.json', 'problem-1832.txt')
# len: 8641
# ('truth-problem-2354.json', 'problem-2354.txt')
# len: 17318
# ('truth-problem-525.json', 'problem-525.txt')
# len: 14002
# ('truth-problem-2716.json', 'problem-2716.txt')
# len: 10974
# ('truth-problem-780.json', 'problem-780.txt')
# len: 13831
# ('truth-problem-1977.json', 'problem-1977.txt')
# len: 6038
# ('truth-problem-3160.json', 'problem-3160.txt')
# len: 10922
# ('truth-problem-3393.json', 'problem-3393.txt')
# len: 10775
# ('truth-problem-884.json', 'problem-884.txt')
# len: 8325
# ('truth-problem-2981.json', 'problem-2981.txt')
# len: 6946
# ('truth-problem-2740.json', 'problem-2740.txt')
# len: 19494
# ('truth-problem-2702.json', 'problem-2702.txt')
# len: 8569
# ('truth-problem-1017.json', 'problem-1017.txt')
# len: 13510
# ('truth-problem-1843.json', 'problem-1843.txt')
# len: 11740
# ('truth-problem-3035.json', 'problem-3035.txt')
# len: 11146
# ('truth-problem-869.json', 'problem-869.txt')
# len: 8409
# ('truth-problem-2053.json', 'problem-2053.txt')
# len: 5993
# ('truth-problem-595.json', 'problem-595.txt')
# len: 17412
# ('truth-problem-3199.json', 'problem-3199.txt')
# len: 13300
# ('truth-problem-222.json', 'problem-222.txt')
# len: 12370
# ('truth-problem-2184.json', 'problem-2184.txt')
# len: 7728
# ('truth-problem-1036.json', 'problem-1036.txt')
# len: 11813
# ('truth-problem-548.json', 'problem-548.txt')
# len: 10368
# ('truth-problem-1260.json', 'problem-1260.txt')
# len: 9968
# ('truth-problem-3053.json', 'problem-3053.txt')
# len: 6362
# ('truth-problem-2683.json', 'problem-2683.txt')
# len: 7393
# ('truth-problem-3340.json', 'problem-3340.txt')
# len: 13913
# ('truth-problem-3307.json', 'problem-3307.txt')
# len: 8440
# ('truth-problem-1345.json', 'problem-1345.txt')
# len: 11034
# ('truth-problem-746.json', 'problem-746.txt')
# len: 12002
# ('truth-problem-1501.json', 'problem-1501.txt')
# len: 8339
# ('truth-problem-2146.json', 'problem-2146.txt')
# len: 11401
# ('truth-problem-60.json', 'problem-60.txt')
# len: 13453
# ('truth-problem-226.json', 'problem-226.txt')
# len: 15628
# ('truth-problem-2109.json', 'problem-2109.txt')
# len: 12914
# ('truth-problem-1528.json', 'problem-1528.txt')
# len: 13565
# ('truth-problem-1399.json', 'problem-1399.txt')
# len: 10723
# ('truth-problem-199.json', 'problem-199.txt')
# len: 7579
# ('truth-problem-1862.json', 'problem-1862.txt')
# len: 16202
# ('truth-problem-531.json', 'problem-531.txt')
# len: 15978
# ('truth-problem-2308.json', 'problem-2308.txt')
# len: 16277
# ('truth-problem-1738.json', 'problem-1738.txt')
# len: 12540
# ('truth-problem-1470.json', 'problem-1470.txt')
# len: 6397
# ('truth-problem-1429.json', 'problem-1429.txt')
# len: 14335
# ('truth-problem-2466.json', 'problem-2466.txt')
# len: 8731
# ('truth-problem-2428.json', 'problem-2428.txt')
# len: 8405
# ('truth-problem-908.json', 'problem-908.txt')
# len: 8917
# ('truth-problem-2565.json', 'problem-2565.txt')
# len: 8030
# ('truth-problem-3338.json', 'problem-3338.txt')
# len: 15371
# ('truth-problem-2983.json', 'problem-2983.txt')
# len: 7757
# ('truth-problem-3076.json', 'problem-3076.txt')
# len: 9465
# ('truth-problem-2988.json', 'problem-2988.txt')
# len: 11416
# ('truth-problem-1627.json', 'problem-1627.txt')
# len: 6853
# ('truth-problem-568.json', 'problem-568.txt')
# len: 6230
# ('truth-problem-2057.json', 'problem-2057.txt')
# len: 16167
# ('truth-problem-1854.json', 'problem-1854.txt')
# len: 12432
# ('truth-problem-2096.json', 'problem-2096.txt')
# len: 8289
# ('truth-problem-2704.json', 'problem-2704.txt')
# len: 15969
# ('truth-problem-1390.json', 'problem-1390.txt')
# len: 11522
# ('truth-problem-2239.json', 'problem-2239.txt')
# len: 14896
# ('truth-problem-1658.json', 'problem-1658.txt')
# len: 7699
# ('truth-problem-2254.json', 'problem-2254.txt')
# len: 8849
# ('truth-problem-3225.json', 'problem-3225.txt')
# len: 7695
# ('truth-problem-59.json', 'problem-59.txt')
# len: 12424
# ('truth-problem-132.json', 'problem-132.txt')
# len: 13229
# ('truth-problem-2907.json', 'problem-2907.txt')
# len: 6810
# ('truth-problem-1375.json', 'problem-1375.txt')
# len: 6662
# ('truth-problem-3315.json', 'problem-3315.txt')
# len: 11459
# ('truth-problem-405.json', 'problem-405.txt')
# len: 13280
# ('truth-problem-3197.json', 'problem-3197.txt')
# len: 16752
# ('truth-problem-1916.json', 'problem-1916.txt')
# len: 7617
# ('truth-problem-495.json', 'problem-495.txt')
# len: 16070
# ('truth-problem-1539.json', 'problem-1539.txt')
# len: 8387
# ('truth-problem-3066.json', 'problem-3066.txt')
# len: 13534
# ('truth-problem-1646.json', 'problem-1646.txt')
# len: 9564
# ('truth-problem-3224.json', 'problem-3224.txt')
# len: 11998
# ('truth-problem-241.json', 'problem-241.txt')
# len: 10965
# ('truth-problem-1333.json', 'problem-1333.txt')
# len: 14206
# ('truth-problem-1611.json', 'problem-1611.txt')
# len: 17315
# ('truth-problem-1300.json', 'problem-1300.txt')
# len: 12409
# ('truth-problem-557.json', 'problem-557.txt')
# len: 17586
# ('truth-problem-1022.json', 'problem-1022.txt')
# len: 12148
# ('truth-problem-1057.json', 'problem-1057.txt')
# len: 14434
# ('truth-problem-229.json', 'problem-229.txt')
# len: 15323
# ('truth-problem-3014.json', 'problem-3014.txt')
# len: 10555
# ('truth-problem-1549.json', 'problem-1549.txt')
# len: 9568
# ('truth-problem-1322.json', 'problem-1322.txt')
# len: 8147
# ('truth-problem-3318.json', 'problem-3318.txt')
# len: 11449
# ('truth-problem-3334.json', 'problem-3334.txt')
# len: 6412
# ('truth-problem-3239.json', 'problem-3239.txt')
# len: 10643
# ('truth-problem-1224.json', 'problem-1224.txt')
# len: 16177
# ('truth-problem-2972.json', 'problem-2972.txt')
# len: 12555
# ('truth-problem-1305.json', 'problem-1305.txt')
# len: 9565
# ('truth-problem-2829.json', 'problem-2829.txt')
# len: 13288
# ('truth-problem-209.json', 'problem-209.txt')
# len: 10796
# ('truth-problem-516.json', 'problem-516.txt')
# len: 9481
# ('truth-problem-1023.json', 'problem-1023.txt')
# len: 12778
# ('truth-problem-749.json', 'problem-749.txt')
# len: 11031
# ('truth-problem-2639.json', 'problem-2639.txt')
# len: 14422
# ('truth-problem-2467.json', 'problem-2467.txt')
# len: 15621
# ('truth-problem-2767.json', 'problem-2767.txt')
# len: 14166
# ('truth-problem-2006.json', 'problem-2006.txt')
# len: 8561
# ('truth-problem-726.json', 'problem-726.txt')
# len: 7021
# ('truth-problem-3407.json', 'problem-3407.txt')
# len: 16479
# ('truth-problem-2827.json', 'problem-2827.txt')
# len: 9631
# ('truth-problem-2525.json', 'problem-2525.txt')
# len: 11681
# ('truth-problem-1145.json', 'problem-1145.txt')
# len: 13523
# ('truth-problem-2771.json', 'problem-2771.txt')
# len: 12973
# ('truth-problem-2591.json', 'problem-2591.txt')
# len: 13690
# ('truth-problem-61.json', 'problem-61.txt')
# len: 14249
# ('truth-problem-3418.json', 'problem-3418.txt')
# len: 6497
# ('truth-problem-2479.json', 'problem-2479.txt')
# len: 12750
# ('truth-problem-3137.json', 'problem-3137.txt')
# len: 12703
# ('truth-problem-1279.json', 'problem-1279.txt')
# len: 8711
# ('truth-problem-1373.json', 'problem-1373.txt')
# len: 6425
# ('truth-problem-3305.json', 'problem-3305.txt')
# len: 7792
# ('truth-problem-79.json', 'problem-79.txt')
# len: 12912
# ('truth-problem-2252.json', 'problem-2252.txt')
# len: 11005
# ('truth-problem-1487.json', 'problem-1487.txt')
# len: 6337
# ('truth-problem-1990.json', 'problem-1990.txt')
# len: 6643
# ('truth-problem-973.json', 'problem-973.txt')
# len: 14945
# ('truth-problem-1715.json', 'problem-1715.txt')
# len: 7393
# ('truth-problem-2023.json', 'problem-2023.txt')
# len: 8914
# ('truth-problem-2930.json', 'problem-2930.txt')
# len: 11965
# ('truth-problem-1463.json', 'problem-1463.txt')
# len: 8686
# ('truth-problem-541.json', 'problem-541.txt')
# len: 12650
# ('truth-problem-2122.json', 'problem-2122.txt')
# len: 15671
# ('truth-problem-2871.json', 'problem-2871.txt')
# len: 17165
# ('truth-problem-1804.json', 'problem-1804.txt')
# len: 10372
# ('truth-problem-2577.json', 'problem-2577.txt')
# len: 9574
# ('truth-problem-924.json', 'problem-924.txt')
# len: 11340
# ('truth-problem-1397.json', 'problem-1397.txt')
# len: 15751
# ('truth-problem-926.json', 'problem-926.txt')
# len: 14306
# ('truth-problem-254.json', 'problem-254.txt')
# len: 6296
# ('truth-problem-3151.json', 'problem-3151.txt')
# len: 6509
# ('truth-problem-3398.json', 'problem-3398.txt')
# len: 7867
# ('truth-problem-1090.json', 'problem-1090.txt')
# len: 14602
# ('truth-problem-2854.json', 'problem-2854.txt')
# len: 17470
# ('truth-problem-1400.json', 'problem-1400.txt')
# len: 7871
# ('truth-problem-2507.json', 'problem-2507.txt')
# len: 19023
# ('truth-problem-1606.json', 'problem-1606.txt')
# len: 6681
# ('truth-problem-2310.json', 'problem-2310.txt')
# len: 16640
# ('truth-problem-2047.json', 'problem-2047.txt')
# len: 12852
# ('truth-problem-342.json', 'problem-342.txt')
# len: 11253
# ('truth-problem-2458.json', 'problem-2458.txt')
# len: 15548
# ('truth-problem-3312.json', 'problem-3312.txt')
# len: 11638
# ('truth-problem-2083.json', 'problem-2083.txt')
# len: 12717
# ('truth-problem-2653.json', 'problem-2653.txt')
# len: 15253
# ('truth-problem-301.json', 'problem-301.txt')
# len: 15256
# ('truth-problem-1943.json', 'problem-1943.txt')
# len: 8748
# ('truth-problem-246.json', 'problem-246.txt')
# len: 11147
# ('truth-problem-1705.json', 'problem-1705.txt')
# len: 13679
# ('truth-problem-1645.json', 'problem-1645.txt')
# len: 8273
# ('truth-problem-2269.json', 'problem-2269.txt')
# len: 20437
# ('truth-problem-1720.json', 'problem-1720.txt')
# len: 14456
# ('truth-problem-386.json', 'problem-386.txt')
# len: 13419
# ('truth-problem-2755.json', 'problem-2755.txt')
# len: 14951
# ('truth-problem-3292.json', 'problem-3292.txt')
# len: 10655
# ('truth-problem-2098.json', 'problem-2098.txt')
# len: 8125
# ('truth-problem-1482.json', 'problem-1482.txt')
# len: 9349
# ('truth-problem-185.json', 'problem-185.txt')
# len: 9526
# ('truth-problem-758.json', 'problem-758.txt')
# len: 10693
# ('truth-problem-2434.json', 'problem-2434.txt')
# len: 18205
# ('truth-problem-2501.json', 'problem-2501.txt')
# len: 10580
# ('truth-problem-2860.json', 'problem-2860.txt')
# len: 16863
# ('truth-problem-538.json', 'problem-538.txt')
# len: 14936
# ('truth-problem-2517.json', 'problem-2517.txt')
# len: 8915
# ('truth-problem-2229.json', 'problem-2229.txt')
# len: 10857
# ('truth-problem-542.json', 'problem-542.txt')
# len: 9852
# ('truth-problem-52.json', 'problem-52.txt')
# len: 11624
# ('truth-problem-946.json', 'problem-946.txt')
# len: 6712
# ('truth-problem-2986.json', 'problem-2986.txt')
# len: 19885
# ('truth-problem-1900.json', 'problem-1900.txt')
# len: 7906
# ('truth-problem-829.json', 'problem-829.txt')
# len: 14310
# ('truth-problem-459.json', 'problem-459.txt')
# len: 8532
# ('truth-problem-1535.json', 'problem-1535.txt')
# len: 8215
# ('truth-problem-3211.json', 'problem-3211.txt')
# len: 15351
# ('truth-problem-3083.json', 'problem-3083.txt')
# len: 12295
# ('truth-problem-2306.json', 'problem-2306.txt')
# len: 13919
# ('truth-problem-1581.json', 'problem-1581.txt')
# len: 14441
# ('truth-problem-63.json', 'problem-63.txt')
# len: 11907
# ('truth-problem-1896.json', 'problem-1896.txt')
# len: 12952
# ('truth-problem-1948.json', 'problem-1948.txt')
# len: 10806
# ('truth-problem-272.json', 'problem-272.txt')
# len: 10956
# ('truth-problem-737.json', 'problem-737.txt')
# len: 5712
# ('truth-problem-2569.json', 'problem-2569.txt')
# len: 11350
# ('truth-problem-3194.json', 'problem-3194.txt')
# len: 16156
# ('truth-problem-674.json', 'problem-674.txt')
# len: 10386
# ('truth-problem-1146.json', 'problem-1146.txt')
# len: 10048
# ('truth-problem-1434.json', 'problem-1434.txt')
# len: 11600
# ('truth-problem-82.json', 'problem-82.txt')
# len: 13419
# ('truth-problem-9.json', 'problem-9.txt')
# len: 16708
# ('truth-problem-2807.json', 'problem-2807.txt')
# len: 17772
# ('truth-problem-727.json', 'problem-727.txt')
# len: 12863
# ('truth-problem-988.json', 'problem-988.txt')
# len: 10117
# ('truth-problem-2522.json', 'problem-2522.txt')
# len: 13283
# ('truth-problem-3047.json', 'problem-3047.txt')
# len: 9634
# ('truth-problem-2350.json', 'problem-2350.txt')
# len: 16462
# ('truth-problem-2821.json', 'problem-2821.txt')
# len: 12036
# ('truth-problem-692.json', 'problem-692.txt')
# len: 13138
# ('truth-problem-1131.json', 'problem-1131.txt')
# len: 13711
# ('truth-problem-824.json', 'problem-824.txt')
# len: 14642
# ('truth-problem-327.json', 'problem-327.txt')
# len: 11074
# ('truth-problem-404.json', 'problem-404.txt')
# len: 15210
# ('truth-problem-1027.json', 'problem-1027.txt')
# len: 8489
# ('truth-problem-3048.json', 'problem-3048.txt')
# len: 12276
# ('truth-problem-2923.json', 'problem-2923.txt')
# len: 11989
# ('truth-problem-1582.json', 'problem-1582.txt')
# len: 14088
# ('truth-problem-23.json', 'problem-23.txt')
# len: 9536
# ('truth-problem-2905.json', 'problem-2905.txt')
# len: 10502
# ('truth-problem-394.json', 'problem-394.txt')
# len: 9677
# ('truth-problem-959.json', 'problem-959.txt')
# len: 12970
# ('truth-problem-665.json', 'problem-665.txt')
# len: 9953
# ('truth-problem-1838.json', 'problem-1838.txt')
# len: 11457
# ('truth-problem-1308.json', 'problem-1308.txt')
# len: 11310
# ('truth-problem-1137.json', 'problem-1137.txt')
# len: 6978
# ('truth-problem-2069.json', 'problem-2069.txt')
# len: 15000
# ('truth-problem-775.json', 'problem-775.txt')
# len: 11708
# ('truth-problem-1555.json', 'problem-1555.txt')
# len: 14986
# ('truth-problem-43.json', 'problem-43.txt')
# len: 9925
# ('truth-problem-1940.json', 'problem-1940.txt')
# len: 8820
# ('truth-problem-1530.json', 'problem-1530.txt')
# len: 10481
# ('truth-problem-2876.json', 'problem-2876.txt')
# len: 9489
# ('truth-problem-1438.json', 'problem-1438.txt')
# len: 6949
# ('truth-problem-360.json', 'problem-360.txt')
# len: 10924
# ('truth-problem-2745.json', 'problem-2745.txt')
# len: 12696
# ('truth-problem-2086.json', 'problem-2086.txt')
# len: 17692
# ('truth-problem-900.json', 'problem-900.txt')
# len: 5843
# ('truth-problem-609.json', 'problem-609.txt')
# len: 7569
# ('truth-problem-1162.json', 'problem-1162.txt')
# len: 8211
# ('truth-problem-2828.json', 'problem-2828.txt')
# len: 8315
# ('truth-problem-3125.json', 'problem-3125.txt')
# len: 15440
# ('truth-problem-292.json', 'problem-292.txt')
# len: 11054
# ('truth-problem-1731.json', 'problem-1731.txt')
# len: 8991
# ('truth-problem-2059.json', 'problem-2059.txt')
# len: 13659
# ('truth-problem-2359.json', 'problem-2359.txt')
# len: 12324
# ('truth-problem-2370.json', 'problem-2370.txt')
# len: 12132
# ('truth-problem-1167.json', 'problem-1167.txt')
# len: 9931
# ('truth-problem-774.json', 'problem-774.txt')
# len: 6163
# ('truth-problem-310.json', 'problem-310.txt')
# len: 14153
# ('truth-problem-3094.json', 'problem-3094.txt')
# len: 12758
# ('truth-problem-3309.json', 'problem-3309.txt')
# len: 7678
# ('truth-problem-1425.json', 'problem-1425.txt')
# len: 15867
# ('truth-problem-76.json', 'problem-76.txt')
# len: 12933
# ('truth-problem-3101.json', 'problem-3101.txt')
# len: 6478
# ('truth-problem-2273.json', 'problem-2273.txt')
# len: 17157
# ('truth-problem-2480.json', 'problem-2480.txt')
# len: 16041
# ('truth-problem-312.json', 'problem-312.txt')
# len: 11009
# ('truth-problem-1561.json', 'problem-1561.txt')
# len: 10264
# ('truth-problem-491.json', 'problem-491.txt')
# len: 11951
# ('truth-problem-1062.json', 'problem-1062.txt')
# len: 15497
# ('truth-problem-2234.json', 'problem-2234.txt')
# len: 12207
# ('truth-problem-146.json', 'problem-146.txt')
# len: 13986
# ('truth-problem-966.json', 'problem-966.txt')
# len: 15883
# ('truth-problem-699.json', 'problem-699.txt')
# len: 11066
# ('truth-problem-1697.json', 'problem-1697.txt')
# len: 15479
# ('truth-problem-1188.json', 'problem-1188.txt')
# len: 13650
# ('truth-problem-2556.json', 'problem-2556.txt')
# len: 8781
# ('truth-problem-522.json', 'problem-522.txt')
# len: 13073
# ('truth-problem-1546.json', 'problem-1546.txt')
# len: 13580
# ('truth-problem-355.json', 'problem-355.txt')
# len: 9123
# ('truth-problem-2792.json', 'problem-2792.txt')
# len: 16930
# ('truth-problem-3090.json', 'problem-3090.txt')
# len: 7908
# ('truth-problem-351.json', 'problem-351.txt')
# len: 6453
# ('truth-problem-3286.json', 'problem-3286.txt')
# len: 10309
# ('truth-problem-945.json', 'problem-945.txt')
# len: 12766
# ('truth-problem-1285.json', 'problem-1285.txt')
# len: 9393
# ('truth-problem-2808.json', 'problem-2808.txt')
# len: 6424
# ('truth-problem-3220.json', 'problem-3220.txt')
# len: 13574
# ('truth-problem-487.json', 'problem-487.txt')
# len: 8361
# ('truth-problem-1863.json', 'problem-1863.txt')
# len: 15177
# ('truth-problem-1665.json', 'problem-1665.txt')
# len: 7871
# ('truth-problem-41.json', 'problem-41.txt')
# len: 10133
# ('truth-problem-2870.json', 'problem-2870.txt')
# len: 7018
# ('truth-problem-671.json', 'problem-671.txt')
# len: 13866
# ('truth-problem-3127.json', 'problem-3127.txt')
# len: 13776
# ('truth-problem-1970.json', 'problem-1970.txt')
# len: 13576
# ('truth-problem-1937.json', 'problem-1937.txt')
# len: 12195
# ('truth-problem-1330.json', 'problem-1330.txt')
# len: 7189
# ('truth-problem-2243.json', 'problem-2243.txt')
# len: 7840
# ('truth-problem-384.json', 'problem-384.txt')
# len: 11583
# ('truth-problem-934.json', 'problem-934.txt')
# len: 7789
# ('truth-problem-2613.json', 'problem-2613.txt')
# len: 7943
# ('truth-problem-3431.json', 'problem-3431.txt')
# len: 7619
# ('truth-problem-1521.json', 'problem-1521.txt')
# len: 11104
# ('truth-problem-567.json', 'problem-567.txt')
# len: 13482
# ('truth-problem-981.json', 'problem-981.txt')
# len: 13806
# ('truth-problem-2564.json', 'problem-2564.txt')
# len: 8549
# ('truth-problem-3201.json', 'problem-3201.txt')
# len: 9435
# ('truth-problem-1947.json', 'problem-1947.txt')
# len: 9616
# ('truth-problem-961.json', 'problem-961.txt')
# len: 15514
# ('truth-problem-2700.json', 'problem-2700.txt')
# len: 13668
# ('truth-problem-3364.json', 'problem-3364.txt')
# len: 7658
# ('truth-problem-710.json', 'problem-710.txt')
# len: 8217
# ('truth-problem-1220.json', 'problem-1220.txt')
# len: 9764
# ('truth-problem-2928.json', 'problem-2928.txt')
# len: 14938
# ('truth-problem-2886.json', 'problem-2886.txt')
# len: 9630
# ('truth-problem-494.json', 'problem-494.txt')
# len: 14703
# ('truth-problem-2670.json', 'problem-2670.txt')
# len: 10671
# ('truth-problem-663.json', 'problem-663.txt')
# len: 10086
# ('truth-problem-1801.json', 'problem-1801.txt')
# len: 6606
# ('truth-problem-324.json', 'problem-324.txt')
# len: 17405
# ('truth-problem-920.json', 'problem-920.txt')
# len: 14513
# ('truth-problem-2444.json', 'problem-2444.txt')
# len: 13671
# ('truth-problem-861.json', 'problem-861.txt')
# len: 7848
# ('truth-problem-465.json', 'problem-465.txt')
# len: 17578
# ('truth-problem-1171.json', 'problem-1171.txt')
# len: 9244
# ('truth-problem-1892.json', 'problem-1892.txt')
# len: 5990
# ('truth-problem-1108.json', 'problem-1108.txt')
# len: 8295
# ('truth-problem-3390.json', 'problem-3390.txt')
# len: 14215
# ('truth-problem-78.json', 'problem-78.txt')
# len: 15699
# ('truth-problem-138.json', 'problem-138.txt')
# len: 6660
# ('truth-problem-1633.json', 'problem-1633.txt')
# len: 15511
# ('truth-problem-2880.json', 'problem-2880.txt')
# len: 11831
# ('truth-problem-3337.json', 'problem-3337.txt')
# len: 6841
# ('truth-problem-2965.json', 'problem-2965.txt')
# len: 7763
# ('truth-problem-1084.json', 'problem-1084.txt')
# len: 8852
# ('truth-problem-1718.json', 'problem-1718.txt')
# len: 6178
# ('truth-problem-3217.json', 'problem-3217.txt')
# len: 12941
# ('truth-problem-2798.json', 'problem-2798.txt')
# len: 12524
# ('truth-problem-3063.json', 'problem-3063.txt')
# len: 7817
# ('truth-problem-3022.json', 'problem-3022.txt')
# len: 17310
# ('truth-problem-2400.json', 'problem-2400.txt')
# len: 18859
# ('truth-problem-2457.json', 'problem-2457.txt')
# len: 13696
# ('truth-problem-1249.json', 'problem-1249.txt')
# len: 12848
# ('truth-problem-831.json', 'problem-831.txt')
# len: 12174
# ('truth-problem-1883.json', 'problem-1883.txt')
# len: 12026
# ('truth-problem-1614.json', 'problem-1614.txt')
# len: 7807
# ('truth-problem-1207.json', 'problem-1207.txt')
# len: 5988
# ('truth-problem-656.json', 'problem-656.txt')
# len: 7469
# ('truth-problem-1538.json', 'problem-1538.txt')
# len: 15654
# ('truth-problem-1719.json', 'problem-1719.txt')
# len: 12381
# ('truth-problem-2171.json', 'problem-2171.txt')
# len: 16432
# ('truth-problem-3130.json', 'problem-3130.txt')
# len: 9517
# ('truth-problem-3200.json', 'problem-3200.txt')
# len: 9453
# ('truth-problem-447.json', 'problem-447.txt')
# len: 7308
# ('truth-problem-3071.json', 'problem-3071.txt')
# len: 7764
# ('truth-problem-1326.json', 'problem-1326.txt')
# len: 5138
# ('truth-problem-2684.json', 'problem-2684.txt')
# len: 7264
# ('truth-problem-3329.json', 'problem-3329.txt')
# len: 10504
# ('truth-problem-3289.json', 'problem-3289.txt')
# len: 11555
# ('truth-problem-648.json', 'problem-648.txt')
# len: 15893
# ('truth-problem-1557.json', 'problem-1557.txt')
# len: 12920
# ('truth-problem-1298.json', 'problem-1298.txt')
# len: 19780
# ('truth-problem-133.json', 'problem-133.txt')
# len: 10050
# ('truth-problem-412.json', 'problem-412.txt')
# len: 17836
# ('truth-problem-2626.json', 'problem-2626.txt')
# len: 8113
# ('truth-problem-1871.json', 'problem-1871.txt')
# len: 15837
# ('truth-problem-2248.json', 'problem-2248.txt')
# len: 19041
# ('truth-problem-834.json', 'problem-834.txt')
# len: 13028
# ('truth-problem-50.json', 'problem-50.txt')
# len: 7454
# ('truth-problem-885.json', 'problem-885.txt')
# len: 11951
# ('truth-problem-196.json', 'problem-196.txt')
# len: 12566
# ('truth-problem-660.json', 'problem-660.txt')
# len: 16186
# ('truth-problem-2062.json', 'problem-2062.txt')
# len: 7970
# ('truth-problem-709.json', 'problem-709.txt')
# len: 14086
# ('truth-problem-1149.json', 'problem-1149.txt')
# len: 7640
# ('truth-problem-129.json', 'problem-129.txt')
# len: 7018
# ('truth-problem-1716.json', 'problem-1716.txt')
# len: 12358
# ('truth-problem-2232.json', 'problem-2232.txt')
# len: 9206
# ('truth-problem-1844.json', 'problem-1844.txt')
# len: 6310
# ('truth-problem-120.json', 'problem-120.txt')
# len: 13757
# ('truth-problem-3391.json', 'problem-3391.txt')
# len: 8494
# ('truth-problem-2017.json', 'problem-2017.txt')
# len: 9461
# ('truth-problem-421.json', 'problem-421.txt')
# len: 7120
# ('truth-problem-2677.json', 'problem-2677.txt')
# len: 9594
# ('truth-problem-1031.json', 'problem-1031.txt')
# len: 12205
# ('truth-problem-815.json', 'problem-815.txt')
# len: 16525
# ('truth-problem-2951.json', 'problem-2951.txt')
# len: 16408
# ('truth-problem-2943.json', 'problem-2943.txt')
# len: 17766
# ('truth-problem-2050.json', 'problem-2050.txt')
# len: 7720
# ('truth-problem-2824.json', 'problem-2824.txt')
# len: 10233
# ('truth-problem-2211.json', 'problem-2211.txt')
# len: 16374
# ('truth-problem-1679.json', 'problem-1679.txt')
# len: 6494
# ('truth-problem-330.json', 'problem-330.txt')
# len: 13623
# ('truth-problem-1472.json', 'problem-1472.txt')
# len: 13683
# ('truth-problem-2562.json', 'problem-2562.txt')
# len: 8240
# ('truth-problem-1989.json', 'problem-1989.txt')
# len: 10608
# ('truth-problem-3068.json', 'problem-3068.txt')
# len: 12979
# ('truth-problem-498.json', 'problem-498.txt')
# len: 16155
# ('truth-problem-1187.json', 'problem-1187.txt')
# len: 9112
# ('truth-problem-1115.json', 'problem-1115.txt')
# len: 16594
# ('truth-problem-3060.json', 'problem-3060.txt')
# len: 11286
# ('truth-problem-3278.json', 'problem-3278.txt')
# len: 6657
# ('truth-problem-2572.json', 'problem-2572.txt')
# len: 16063
# ('truth-problem-2837.json', 'problem-2837.txt')
# len: 11251
# ('truth-problem-3299.json', 'problem-3299.txt')
# len: 14826
# ('truth-problem-2140.json', 'problem-2140.txt')
# len: 14458
# ('truth-problem-1853.json', 'problem-1853.txt')
# len: 8022
# ('truth-problem-299.json', 'problem-299.txt')
# len: 11412
# ('truth-problem-1885.json', 'problem-1885.txt')
# len: 8714
# ('truth-problem-1912.json', 'problem-1912.txt')
# len: 12149
# ('truth-problem-2142.json', 'problem-2142.txt')
# len: 16558
# ('truth-problem-62.json', 'problem-62.txt')
# len: 8284
# ('truth-problem-1891.json', 'problem-1891.txt')
# len: 13903
# ('truth-problem-118.json', 'problem-118.txt')
# len: 8926
# ('truth-problem-3257.json', 'problem-3257.txt')
# len: 13118
# ('truth-problem-489.json', 'problem-489.txt')
# len: 11584
# ('truth-problem-372.json', 'problem-372.txt')
# len: 10159
# ('truth-problem-2732.json', 'problem-2732.txt')
# len: 13903
# ('truth-problem-2599.json', 'problem-2599.txt')
# len: 10174
# ('truth-problem-2520.json', 'problem-2520.txt')
# len: 15257
# ('truth-problem-1405.json', 'problem-1405.txt')
# len: 8430
# ('truth-problem-1810.json', 'problem-1810.txt')
# len: 13391
# ('truth-problem-1983.json', 'problem-1983.txt')
# len: 11312
# ('truth-problem-3304.json', 'problem-3304.txt')
# len: 8897
# ('truth-problem-485.json', 'problem-485.txt')
# len: 9922
# ('truth-problem-641.json', 'problem-641.txt')
# len: 9515
# ('truth-problem-1424.json', 'problem-1424.txt')
# len: 9047
# ('truth-problem-2033.json', 'problem-2033.txt')
# len: 7847
# ('truth-problem-2416.json', 'problem-2416.txt')
# len: 10834
# ('truth-problem-1887.json', 'problem-1887.txt')
# len: 13193
# ('truth-problem-880.json', 'problem-880.txt')
# len: 9038
# ('truth-problem-2237.json', 'problem-2237.txt')
# len: 7412
# ('truth-problem-265.json', 'problem-265.txt')
# len: 15335
# ('truth-problem-286.json', 'problem-286.txt')
# len: 12355
# ('truth-problem-1237.json', 'problem-1237.txt')
# len: 15759
# ('truth-problem-1564.json', 'problem-1564.txt')
# len: 10587
# ('truth-problem-1818.json', 'problem-1818.txt')
# len: 5674
# ('truth-problem-407.json', 'problem-407.txt')
# len: 15773
# ('truth-problem-3311.json', 'problem-3311.txt')
# len: 10866
# ('truth-problem-696.json', 'problem-696.txt')
# len: 9253
# ('truth-problem-1570.json', 'problem-1570.txt')
# len: 11897
# ('truth-problem-2463.json', 'problem-2463.txt')
# len: 20588
# ('truth-problem-3245.json', 'problem-3245.txt')
# len: 7757
# ('truth-problem-3397.json', 'problem-3397.txt')
# len: 14360
# ('truth-problem-1834.json', 'problem-1834.txt')
# len: 5931
# ('truth-problem-929.json', 'problem-929.txt')
# len: 16176
# ('truth-problem-1852.json', 'problem-1852.txt')
# len: 9737
# ('truth-problem-1446.json', 'problem-1446.txt')
# len: 10934
# ('truth-problem-1690.json', 'problem-1690.txt')
# len: 14220
# ('truth-problem-2071.json', 'problem-2071.txt')
# len: 10475
# ('truth-problem-415.json', 'problem-415.txt')
# len: 13607
# ('truth-problem-1227.json', 'problem-1227.txt')
# len: 7523
# ('truth-problem-3287.json', 'problem-3287.txt')
# len: 6098
# ('truth-problem-2739.json', 'problem-2739.txt')
# len: 11440
# ('truth-problem-2277.json', 'problem-2277.txt')
# len: 14259
# ('truth-problem-1192.json', 'problem-1192.txt')
# len: 6395
# ('truth-problem-832.json', 'problem-832.txt')
# len: 9148
# ('truth-problem-1222.json', 'problem-1222.txt')
# len: 14517
# ('truth-problem-1419.json', 'problem-1419.txt')
# len: 8667
# ('truth-problem-635.json', 'problem-635.txt')
# len: 9009
# ('truth-problem-2760.json', 'problem-2760.txt')
# len: 12012
# ('truth-problem-1245.json', 'problem-1245.txt')
# len: 8844
# ('truth-problem-3115.json', 'problem-3115.txt')
# len: 8106
# ('truth-problem-2376.json', 'problem-2376.txt')
# len: 6862
# ('truth-problem-151.json', 'problem-151.txt')
# len: 9795
# ('truth-problem-107.json', 'problem-107.txt')
# len: 10738
# ('truth-problem-582.json', 'problem-582.txt')
# len: 9521
# ('truth-problem-2738.json', 'problem-2738.txt')
# len: 6374
# ('truth-problem-3173.json', 'problem-3173.txt')
# len: 16918
# ('truth-problem-166.json', 'problem-166.txt')
# len: 15034
# ('truth-problem-93.json', 'problem-93.txt')
# len: 14556
# ('truth-problem-227.json', 'problem-227.txt')
# len: 10194
# ('truth-problem-3166.json', 'problem-3166.txt')
# len: 13380
# ('truth-problem-1356.json', 'problem-1356.txt')
# len: 10889
# ('truth-problem-1571.json', 'problem-1571.txt')
# len: 9271
# ('truth-problem-456.json', 'problem-456.txt')
# len: 7965
# ('truth-problem-2393.json', 'problem-2393.txt')
# len: 7952
# ('truth-problem-3144.json', 'problem-3144.txt')
# len: 12857
# ('truth-problem-3042.json', 'problem-3042.txt')
# len: 11225
# ('truth-problem-3142.json', 'problem-3142.txt')
# len: 15334
# ('truth-problem-1710.json', 'problem-1710.txt')
# len: 13099
# ('truth-problem-1337.json', 'problem-1337.txt')
# len: 13867
# ('truth-problem-195.json', 'problem-195.txt')
# len: 12387
# ('truth-problem-244.json', 'problem-244.txt')
# len: 16462
# ('truth-problem-1315.json', 'problem-1315.txt')
# len: 16480
# ('truth-problem-1247.json', 'problem-1247.txt')
# len: 7445
# ('truth-problem-2268.json', 'problem-2268.txt')
# len: 14443
# ('truth-problem-1046.json', 'problem-1046.txt')
# len: 12444
# ('truth-problem-854.json', 'problem-854.txt')
# len: 6187
# ('truth-problem-3260.json', 'problem-3260.txt')
# len: 13453
# ('truth-problem-2726.json', 'problem-2726.txt')
# len: 13052
# ('truth-problem-1510.json', 'problem-1510.txt')
# len: 5793
# ('truth-problem-533.json', 'problem-533.txt')
# len: 13418
# ('truth-problem-666.json', 'problem-666.txt')
# len: 8659
# ('truth-problem-559.json', 'problem-559.txt')
# len: 14581
# ('truth-problem-2509.json', 'problem-2509.txt')
# len: 16080
# ('truth-problem-1009.json', 'problem-1009.txt')
# len: 18392
# ('truth-problem-1289.json', 'problem-1289.txt')
# len: 16903
# ('truth-problem-868.json', 'problem-868.txt')
# len: 13007
# ('truth-problem-657.json', 'problem-657.txt')
# len: 15976
# ('truth-problem-2282.json', 'problem-2282.txt')
# len: 6541
# ('truth-problem-45.json', 'problem-45.txt')
# len: 16314
# ('truth-problem-40.json', 'problem-40.txt')
# len: 14320
# ('truth-problem-1910.json', 'problem-1910.txt')
# len: 11828
# ('truth-problem-2661.json', 'problem-2661.txt')
# len: 8366
# ('truth-problem-3432.json', 'problem-3432.txt')
# len: 10735
# ('truth-problem-3379.json', 'problem-3379.txt')
# len: 9523
# ('truth-problem-898.json', 'problem-898.txt')
# len: 9861
# ('truth-problem-2778.json', 'problem-2778.txt')
# len: 8838
# ('truth-problem-555.json', 'problem-555.txt')
# len: 11202
# ('truth-problem-1777.json', 'problem-1777.txt')
# len: 9071
# ('truth-problem-72.json', 'problem-72.txt')
# len: 19357
# ('truth-problem-1747.json', 'problem-1747.txt')
# len: 6618
# ('truth-problem-1636.json', 'problem-1636.txt')
# len: 15501
# ('truth-problem-2881.json', 'problem-2881.txt')
# len: 5899
# ('truth-problem-2497.json', 'problem-2497.txt')
# len: 13544
# ('truth-problem-1055.json', 'problem-1055.txt')
# len: 16409
# ('truth-problem-3119.json', 'problem-3119.txt')
# len: 11978
# ('truth-problem-1978.json', 'problem-1978.txt')
# len: 12498
# ('truth-problem-191.json', 'problem-191.txt')
# len: 11574
# ('truth-problem-87.json', 'problem-87.txt')
# len: 13842
# ('truth-problem-1294.json', 'problem-1294.txt')
# len: 17768
# ('truth-problem-2793.json', 'problem-2793.txt')
# len: 7785
# ('truth-problem-2888.json', 'problem-2888.txt')
# len: 14137
# ('truth-problem-1094.json', 'problem-1094.txt')
# len: 8692
# ('truth-problem-2857.json', 'problem-2857.txt')
# len: 17435
# ('truth-problem-2173.json', 'problem-2173.txt')
# len: 17715
# ('truth-problem-1354.json', 'problem-1354.txt')
# len: 11769
# ('truth-problem-2289.json', 'problem-2289.txt')
# len: 18930
# ('truth-problem-2205.json', 'problem-2205.txt')
# len: 18660
# ('truth-problem-1692.json', 'problem-1692.txt')
# len: 11937
# ('truth-problem-349.json', 'problem-349.txt')
# len: 8844
# ('truth-problem-2875.json', 'problem-2875.txt')
# len: 8494
# ('truth-problem-1640.json', 'problem-1640.txt')
# len: 9692
# ('truth-problem-2971.json', 'problem-2971.txt')
# len: 12035
# ('truth-problem-2210.json', 'problem-2210.txt')
# len: 8159
# ('truth-problem-390.json', 'problem-390.txt')
# len: 15370
# ('truth-problem-623.json', 'problem-623.txt')
# len: 9611
# ('truth-problem-1992.json', 'problem-1992.txt')
# len: 14452
# ('truth-problem-2189.json', 'problem-2189.txt')
# len: 16443
# ('truth-problem-3104.json', 'problem-3104.txt')
# len: 10507
# ('truth-problem-2034.json', 'problem-2034.txt')
# len: 12698
# ('truth-problem-3350.json', 'problem-3350.txt')
# len: 14314
# ('truth-problem-2856.json', 'problem-2856.txt')
# len: 12234
# ('truth-problem-2544.json', 'problem-2544.txt')
# len: 14602
# ('truth-problem-1225.json', 'problem-1225.txt')
# len: 11069
# ('truth-problem-1556.json', 'problem-1556.txt')
# len: 7234
# ('truth-problem-3394.json', 'problem-3394.txt')
# len: 15140
# ('truth-problem-3088.json', 'problem-3088.txt')
# len: 12650
# ('truth-problem-2775.json', 'problem-2775.txt')
# len: 8229
# ('truth-problem-715.json', 'problem-715.txt')
# len: 8161
# ('truth-problem-2772.json', 'problem-2772.txt')
# len: 16931
# ('truth-problem-1442.json', 'problem-1442.txt')
# len: 11390
# ('truth-problem-2.json', 'problem-2.txt')
# len: 13328
# ('truth-problem-925.json', 'problem-925.txt')
# len: 8383
# ('truth-problem-2436.json', 'problem-2436.txt')
# len: 16002
# ('truth-problem-901.json', 'problem-901.txt')
# len: 9872
# ('truth-problem-3243.json', 'problem-3243.txt')
# len: 14640
# ('truth-problem-765.json', 'problem-765.txt')
# len: 17500
# ('truth-problem-2672.json', 'problem-2672.txt')
# len: 13220
# ('truth-problem-1794.json', 'problem-1794.txt')
# len: 9966
# ('truth-problem-530.json', 'problem-530.txt')
# len: 8747
# ('truth-problem-2878.json', 'problem-2878.txt')
# len: 12147
# ('truth-problem-3294.json', 'problem-3294.txt')
# len: 15283
# ('truth-problem-2295.json', 'problem-2295.txt')
# len: 13163
# ('truth-problem-783.json', 'problem-783.txt')
# len: 12325
# ('truth-problem-1967.json', 'problem-1967.txt')
# len: 8303
# ('truth-problem-1428.json', 'problem-1428.txt')
# len: 15290
# ('truth-problem-2390.json', 'problem-2390.txt')
# len: 12849
# ('truth-problem-461.json', 'problem-461.txt')
# len: 16862
# ('truth-problem-267.json', 'problem-267.txt')
# len: 12107
# ('truth-problem-2733.json', 'problem-2733.txt')
# len: 8821
# ('truth-problem-1693.json', 'problem-1693.txt')
# len: 14322
# ('truth-problem-2344.json', 'problem-2344.txt')
# len: 18368
# ('truth-problem-2576.json', 'problem-2576.txt')
# len: 6511
# ('truth-problem-622.json', 'problem-622.txt')
# len: 16870
# ('truth-problem-3413.json', 'problem-3413.txt')
# len: 9168
# ('truth-problem-366.json', 'problem-366.txt')
# len: 8447
# ('truth-problem-32.json', 'problem-32.txt')
# len: 9147
# ('truth-problem-1371.json', 'problem-1371.txt')
# len: 7455
# ('truth-problem-2715.json', 'problem-2715.txt')
# len: 15551
# ('truth-problem-2669.json', 'problem-2669.txt')
# len: 13521
# ('truth-problem-115.json', 'problem-115.txt')
# len: 13768
# ('truth-problem-1381.json', 'problem-1381.txt')
# len: 11566
# ('truth-problem-2309.json', 'problem-2309.txt')
# len: 18357
# ('truth-problem-1230.json', 'problem-1230.txt')
# len: 13697
# ('truth-problem-1651.json', 'problem-1651.txt')
# len: 15681
# ('truth-problem-2459.json', 'problem-2459.txt')
# len: 13774
# ('truth-problem-2035.json', 'problem-2035.txt')
# len: 12354
# ('truth-problem-2222.json', 'problem-2222.txt')
# len: 19366
# ('truth-problem-3025.json', 'problem-3025.txt')
# len: 8759
# ('truth-problem-2809.json', 'problem-2809.txt')
# len: 15562
# ('truth-problem-654.json', 'problem-654.txt')
# len: 8328
# ('truth-problem-1532.json', 'problem-1532.txt')
# len: 13490
# ('truth-problem-2075.json', 'problem-2075.txt')
# len: 11329
# ('truth-problem-1869.json', 'problem-1869.txt')
# len: 12812
# ...
# len: 16728
# ('truth-problem-1526.json', 'problem-1526.txt')
# len: 6947
# ('truth-problem-2394.json', 'problem-2394.txt')
# len: 16900
# ('truth-problem-1506.json', 'problem-1506.txt')
# len: 8249
# ('truth-problem-912.json', 'problem-912.txt')
# len: 9229
# ('truth-problem-2996.json', 'problem-2996.txt')
# len: 15015
# ('truth-problem-1508.json', 'problem-1508.txt')
# len: 14676
# ('truth-problem-646.json', 'problem-646.txt')
# len: 10426
# ('truth-problem-864.json', 'problem-864.txt')
# len: 14659
# ('truth-problem-2647.json', 'problem-2647.txt')
# len: 15023
# ('truth-problem-140.json', 'problem-140.txt')
# len: 7920
# ('truth-problem-2645.json', 'problem-2645.txt')
# len: 15477
# ('truth-problem-781.json', 'problem-781.txt')
# len: 11323
# ('truth-problem-1685.json', 'problem-1685.txt')
# len: 17537
# ('truth-problem-3372.json', 'problem-3372.txt')
# len: 17032
# ('truth-problem-1728.json', 'problem-1728.txt')
# len: 7625
# ('truth-problem-1507.json', 'problem-1507.txt')
# len: 13070
# ('truth-problem-1499.json', 'problem-1499.txt')
# len: 10881
# ('truth-problem-2192.json', 'problem-2192.txt')
# len: 14419
# ('truth-problem-2039.json', 'problem-2039.txt')
# len: 7681
# ('truth-problem-3316.json', 'problem-3316.txt')
# len: 7962
# ('truth-problem-574.json', 'problem-574.txt')
# len: 13408
# ('truth-problem-2338.json', 'problem-2338.txt')
# len: 14865
# ('truth-problem-1321.json', 'problem-1321.txt')
# len: 15733
# ('truth-problem-2949.json', 'problem-2949.txt')
# len: 13052
# ('truth-problem-2652.json', 'problem-2652.txt')
# len: 11347
# ('truth-problem-3154.json', 'problem-3154.txt')
# len: 7649
# ('truth-problem-1643.json', 'problem-1643.txt')
# len: 12462
# ('truth-problem-3433.json', 'problem-3433.txt')
# len: 13581
# ('truth-problem-2995.json', 'problem-2995.txt')
# len: 12426
# ('truth-problem-1395.json', 'problem-1395.txt')
# len: 10031
# ('truth-problem-1949.json', 'problem-1949.txt')
# len: 8429
# ('truth-problem-1628.json', 'problem-1628.txt')
# len: 8915
# ('truth-problem-255.json', 'problem-255.txt')
# len: 14837
# ('truth-problem-1002.json', 'problem-1002.txt')
# len: 15727
# ('truth-problem-353.json', 'problem-353.txt')
# len: 13536
# ('truth-problem-1696.json', 'problem-1696.txt')
# len: 7945
# ('truth-problem-452.json', 'problem-452.txt')
# len: 13031
# ('truth-problem-544.json', 'problem-544.txt')
# len: 14726
# ('truth-problem-2614.json', 'problem-2614.txt')
# len: 13638
# ('truth-problem-1952.json', 'problem-1952.txt')
# len: 8467
# ('truth-problem-2208.json', 'problem-2208.txt')
# len: 9129
# ('truth-problem-53.json', 'problem-53.txt')
# len: 13105
# ('truth-problem-1408.json', 'problem-1408.txt')
# len: 5735
# ('truth-problem-1972.json', 'problem-1972.txt')
# len: 9204
# ('truth-problem-528.json', 'problem-528.txt')
# len: 7846
# ('truth-problem-935.json', 'problem-935.txt')
# len: 15232
# ('truth-problem-1899.json', 'problem-1899.txt')
# len: 12959
# ('truth-problem-554.json', 'problem-554.txt')
# len: 13007
# ('truth-problem-58.json', 'problem-58.txt')
# len: 18720
# ('truth-problem-1802.json', 'problem-1802.txt')
# len: 9958
# ('truth-problem-2130.json', 'problem-2130.txt')
# len: 8594
# ('truth-problem-1954.json', 'problem-1954.txt')
# len: 9316
# ('truth-problem-1343.json', 'problem-1343.txt')
# len: 15422
# ('truth-problem-1318.json', 'problem-1318.txt')
# len: 10230
# ('truth-problem-2734.json', 'problem-2734.txt')
# len: 14703
# ('truth-problem-1525.json', 'problem-1525.txt')
# len: 16208
# ('truth-problem-630.json', 'problem-630.txt')
# len: 13760
# ('truth-problem-3134.json', 'problem-3134.txt')
# len: 8827
# ('truth-problem-990.json', 'problem-990.txt')
# len: 5903
# ('truth-problem-1329.json', 'problem-1329.txt')
# len: 8312
# ('truth-problem-584.json', 'problem-584.txt')
# len: 14521
# ('truth-problem-2764.json', 'problem-2764.txt')
# len: 9572
# ('truth-problem-1781.json', 'problem-1781.txt')
# len: 14570
# ('truth-problem-2052.json', 'problem-2052.txt')
# len: 8243
# ('truth-problem-1246.json', 'problem-1246.txt')
# len: 10490
# ('truth-problem-897.json', 'problem-897.txt')
# len: 14382
# ('truth-problem-112.json', 'problem-112.txt')
# len: 13831
# ('truth-problem-3092.json', 'problem-3092.txt')
# len: 12360
# ('truth-problem-2938.json', 'problem-2938.txt')
# len: 14306
# ('truth-problem-1214.json', 'problem-1214.txt')
# len: 8778
# ('truth-problem-1365.json', 'problem-1365.txt')
# len: 11979
# ('truth-problem-2908.json', 'problem-2908.txt')
# len: 15309
# ('truth-problem-3075.json', 'problem-3075.txt')
# len: 12534
# ('truth-problem-2067.json', 'problem-2067.txt')
# len: 7459
# ('truth-problem-2955.json', 'problem-2955.txt')
# len: 15537
# ('truth-problem-3400.json', 'problem-3400.txt')
# len: 16608
# ('truth-problem-1153.json', 'problem-1153.txt')
# len: 11878
# ('truth-problem-1653.json', 'problem-1653.txt')
# len: 6728
# ('truth-problem-2810.json', 'problem-2810.txt')
# len: 9497
# ('truth-problem-798.json', 'problem-798.txt')
# len: 15740
# ('truth-problem-375.json', 'problem-375.txt')
# len: 8450
# ('truth-problem-2665.json', 'problem-2665.txt')
# len: 13762
# ('truth-problem-698.json', 'problem-698.txt')
# len: 5420
# ('truth-problem-463.json', 'problem-463.txt')
# len: 9587
# ('truth-problem-1861.json', 'problem-1861.txt')
# len: 14434
# ('truth-problem-1431.json', 'problem-1431.txt')
# len: 17191
# ('truth-problem-795.json', 'problem-795.txt')
# len: 10977
# ('truth-problem-206.json', 'problem-206.txt')
# len: 10809
# ('truth-problem-1311.json', 'problem-1311.txt')
# len: 15463
# ('truth-problem-55.json', 'problem-55.txt')
# len: 15105
# ('truth-problem-1495.json', 'problem-1495.txt')
# len: 5702
# ('truth-problem-606.json', 'problem-606.txt')
# len: 9485
# ('truth-problem-1026.json', 'problem-1026.txt')
# len: 8638
# ('truth-problem-3061.json', 'problem-3061.txt')
# len: 15365
# ('truth-problem-3424.json', 'problem-3424.txt')
# len: 9940
# ('truth-problem-157.json', 'problem-157.txt')
# len: 6088
# ('truth-problem-2228.json', 'problem-2228.txt')
# len: 9653
# ('truth-problem-331.json', 'problem-331.txt')
# len: 9318
# ('truth-problem-1591.json', 'problem-1591.txt')
# len: 7161
# ('truth-problem-904.json', 'problem-904.txt')
# len: 12033
# ('truth-problem-1703.json', 'problem-1703.txt')
# len: 8905
# ('truth-problem-2518.json', 'problem-2518.txt')
# len: 10531
# ('truth-problem-2511.json', 'problem-2511.txt')
# len: 16460
# ('truth-problem-1927.json', 'problem-1927.txt')
# len: 14704
# ('truth-problem-2446.json', 'problem-2446.txt')
# len: 9017
# ('truth-problem-1817.json', 'problem-1817.txt')
# len: 13810
# ('truth-problem-2721.json', 'problem-2721.txt')
# len: 15224
# ('truth-problem-219.json', 'problem-219.txt')
# len: 11507
# ('truth-problem-2891.json', 'problem-2891.txt')
# len: 11455
# ('truth-problem-686.json', 'problem-686.txt')
# len: 8348
# ('truth-problem-3336.json', 'problem-3336.txt')
# len: 11405
# ('truth-problem-1132.json', 'problem-1132.txt')
# len: 18135
# ('truth-problem-340.json', 'problem-340.txt')
# len: 11204
# ('truth-problem-2235.json', 'problem-2235.txt')
# len: 8545
# ('truth-problem-3259.json', 'problem-3259.txt')
# len: 15196
# ('truth-problem-3420.json', 'problem-3420.txt')
# len: 7945
# ('truth-problem-1100.json', 'problem-1100.txt')
# len: 11586
# ('truth-problem-576.json', 'problem-576.txt')
# len: 12586
# ('truth-problem-1687.json', 'problem-1687.txt')
# len: 13665
# ('truth-problem-2964.json', 'problem-2964.txt')
# len: 18036
# ('truth-problem-2601.json', 'problem-2601.txt')
# len: 18489
# ('truth-problem-2398.json', 'problem-2398.txt')
# len: 11483
# ('truth-problem-2830.json', 'problem-2830.txt')
# len: 14653
# ('truth-problem-14.json', 'problem-14.txt')
# len: 7524
# ('truth-problem-1263.json', 'problem-1263.txt')
# len: 11458
# ('truth-problem-1135.json', 'problem-1135.txt')
# len: 7944
# ('truth-problem-2174.json', 'problem-2174.txt')
# len: 13877
# ('truth-problem-428.json', 'problem-428.txt')
# len: 10913
# ('truth-problem-2644.json', 'problem-2644.txt')
# len: 10285
# ('truth-problem-317.json', 'problem-317.txt')
# len: 10704
# ('truth-problem-1698.json', 'problem-1698.txt')
# len: 16219
# ('truth-problem-3296.json', 'problem-3296.txt')
# len: 17657
# ('truth-problem-1500.json', 'problem-1500.txt')
# len: 12000
# ('truth-problem-2651.json', 'problem-2651.txt')
# len: 14726
# ('truth-problem-1600.json', 'problem-1600.txt')
# len: 11416
# ('truth-problem-3234.json', 'problem-3234.txt')
# len: 10711
# ('truth-problem-1942.json', 'problem-1942.txt')
# len: 11499
# ('truth-problem-1189.json', 'problem-1189.txt')
# len: 8595
# ('truth-problem-2703.json', 'problem-2703.txt')
# len: 16751
# ('truth-problem-3205.json', 'problem-3205.txt')
# len: 14541
# ('truth-problem-285.json', 'problem-285.txt')
# len: 15138
# ('truth-problem-1598.json', 'problem-1598.txt')
# len: 9286
# ('truth-problem-2118.json', 'problem-2118.txt')
# len: 15226
# ('truth-problem-5.json', 'problem-5.txt')
# len: 13448
# ('truth-problem-2833.json', 'problem-2833.txt')
# len: 16765
# ('truth-problem-1941.json', 'problem-1941.txt')
# len: 15669
# ('truth-problem-467.json', 'problem-467.txt')
# len: 5932
# ('truth-problem-1468.json', 'problem-1468.txt')
# len: 8480
# ('truth-problem-1709.json', 'problem-1709.txt')
# len: 10874
# ('truth-problem-2286.json', 'problem-2286.txt')
# len: 14683
# ('truth-problem-1129.json', 'problem-1129.txt')
# len: 14265
# ('truth-problem-2423.json', 'problem-2423.txt')
# len: 9248
# ('truth-problem-2179.json', 'problem-2179.txt')
# len: 10108
# ('truth-problem-2365.json', 'problem-2365.txt')
# len: 17562
# ('truth-problem-1695.json', 'problem-1695.txt')
# len: 14984
# ('truth-problem-201.json', 'problem-201.txt')
# len: 15122
# ('truth-problem-2327.json', 'problem-2327.txt')
# len: 16726
# ('truth-problem-979.json', 'problem-979.txt')
# len: 6481
# ('truth-problem-442.json', 'problem-442.txt')
# len: 10983
# ('truth-problem-304.json', 'problem-304.txt')
# len: 11340
# ('truth-problem-1680.json', 'problem-1680.txt')
# len: 10574
# ('truth-problem-2494.json', 'problem-2494.txt')
# len: 14977
# ('truth-problem-1514.json', 'problem-1514.txt')
# len: 10344
# ('truth-problem-210.json', 'problem-210.txt')
# len: 7610
# ('truth-problem-1060.json', 'problem-1060.txt')
# len: 12623
# ('truth-problem-896.json', 'problem-896.txt')
# len: 15289
# ('truth-problem-1592.json', 'problem-1592.txt')
# len: 6639
# ('truth-problem-462.json', 'problem-462.txt')
# len: 13882
# ('truth-problem-1154.json', 'problem-1154.txt')
# len: 16572
# ('truth-problem-1158.json', 'problem-1158.txt')
# len: 10300
# ('truth-problem-1114.json', 'problem-1114.txt')
# len: 16085
# ('truth-problem-2948.json', 'problem-2948.txt')
# len: 6632
# ('truth-problem-3021.json', 'problem-3021.txt')
# len: 10910
# ('truth-problem-1372.json', 'problem-1372.txt')
# len: 12523
# ('truth-problem-1594.json', 'problem-1594.txt')
# len: 13609
# ('truth-problem-143.json', 'problem-143.txt')
# len: 16145
# ('truth-problem-316.json', 'problem-316.txt')
# len: 16243
# ('truth-problem-2512.json', 'problem-2512.txt')
# len: 11446
# ('truth-problem-433.json', 'problem-433.txt')
# len: 11429
# ('truth-problem-1203.json', 'problem-1203.txt')
# len: 10133
# ('truth-problem-3248.json', 'problem-3248.txt')
# len: 6732
# ('truth-problem-3270.json', 'problem-3270.txt')
# len: 5620
# ('truth-problem-2276.json', 'problem-2276.txt')
# len: 17979
# ('truth-problem-1629.json', 'problem-1629.txt')
# len: 13579
# ('truth-problem-1276.json', 'problem-1276.txt')
# len: 12104
# ('truth-problem-1462.json', 'problem-1462.txt')
# len: 8503
# ('truth-problem-3353.json', 'problem-3353.txt')
# len: 11556
# ('truth-problem-3170.json', 'problem-3170.txt')
# len: 6757
# ('truth-problem-1465.json', 'problem-1465.txt')
# len: 13994
# ('truth-problem-2594.json', 'problem-2594.txt')
# len: 14853
# ('truth-problem-928.json', 'problem-928.txt')
# len: 14034
# ('truth-problem-1987.json', 'problem-1987.txt')
# len: 10218
# ('truth-problem-3167.json', 'problem-3167.txt')
# len: 11309
# ('truth-problem-2005.json', 'problem-2005.txt')
# len: 14428
# ('truth-problem-1504.json', 'problem-1504.txt')
# len: 9511
# ('truth-problem-3102.json', 'problem-3102.txt')
# len: 14437
# ('truth-problem-3319.json', 'problem-3319.txt')
# len: 7816
# ('truth-problem-2426.json', 'problem-2426.txt')
# len: 10228
# ('truth-problem-1851.json', 'problem-1851.txt')
# len: 10717
# ('truth-problem-256.json', 'problem-256.txt')
# len: 9469
# ('truth-problem-2469.json', 'problem-2469.txt')
# len: 16357
# ('truth-problem-963.json', 'problem-963.txt')
# len: 10070
# ('truth-problem-2629.json', 'problem-2629.txt')
# len: 9999
# ('truth-problem-3354.json', 'problem-3354.txt')
# len: 16571
# ('truth-problem-2648.json', 'problem-2648.txt')
# len: 14408
# ('truth-problem-2279.json', 'problem-2279.txt')
# len: 13621
# ('truth-problem-1271.json', 'problem-1271.txt')
# len: 13214
# ('truth-problem-1676.json', 'problem-1676.txt')
# len: 14482
# ('truth-problem-637.json', 'problem-637.txt')
# len: 15091
# ('truth-problem-767.json', 'problem-767.txt')
# len: 12173
# ('truth-problem-1091.json', 'problem-1091.txt')
# len: 12502
# ('truth-problem-3382.json', 'problem-3382.txt')
# len: 6361
# ('truth-problem-913.json', 'problem-913.txt')
# len: 9626
# ('truth-problem-86.json', 'problem-86.txt')
# len: 10775
# ('truth-problem-3140.json', 'problem-3140.txt')
# len: 8458
# ('truth-problem-672.json', 'problem-672.txt')
# len: 11422
# ('truth-problem-1607.json', 'problem-1607.txt')
# len: 10445
# ('truth-problem-2531.json', 'problem-2531.txt')
# len: 10930
# ('truth-problem-2108.json', 'problem-2108.txt')
# len: 7283
# ('truth-problem-2718.json', 'problem-2718.txt')
# len: 11870
# ('truth-problem-617.json', 'problem-617.txt')
# len: 11330
# ('truth-problem-1067.json', 'problem-1067.txt')
# len: 13704
# ('truth-problem-586.json', 'problem-586.txt')
# len: 13019
# ('truth-problem-278.json', 'problem-278.txt')
# len: 16130
# ('truth-problem-1721.json', 'problem-1721.txt')
# len: 9480
# ('truth-problem-1376.json', 'problem-1376.txt')
# len: 15616
# ('truth-problem-2342.json', 'problem-2342.txt')
# len: 18401
# ('truth-problem-1176.json', 'problem-1176.txt')
# len: 15319
# ('truth-problem-2695.json', 'problem-2695.txt')
# len: 6836
# ('truth-problem-3258.json', 'problem-3258.txt')
# len: 12440
# ('truth-problem-3114.json', 'problem-3114.txt')
# len: 11641
# ('truth-problem-2898.json', 'problem-2898.txt')
# len: 14231
# ('truth-problem-3237.json', 'problem-3237.txt')
# len: 9533
# ('truth-problem-431.json', 'problem-431.txt')
# len: 8547
# ('truth-problem-3373.json', 'problem-3373.txt')
# len: 11870
# ('truth-problem-3062.json', 'problem-3062.txt')
# len: 11481
# ('truth-problem-2873.json', 'problem-2873.txt')
# len: 12786
# ('truth-problem-66.json', 'problem-66.txt')
# len: 14911
# ('truth-problem-1682.json', 'problem-1682.txt')
# len: 16450
# ('truth-problem-825.json', 'problem-825.txt')
# len: 12633
# ('truth-problem-983.json', 'problem-983.txt')
# len: 7991
# ('truth-problem-3244.json', 'problem-3244.txt')
# len: 13997
# ('truth-problem-658.json', 'problem-658.txt')
# len: 7881
# ('truth-problem-1791.json', 'problem-1791.txt')
# len: 7054
# ('truth-problem-3360.json', 'problem-3360.txt')
# len: 12987
# ('truth-problem-2201.json', 'problem-2201.txt')
# len: 12481
# ('truth-problem-1701.json', 'problem-1701.txt')
# len: 8570
# ('truth-problem-2530.json', 'problem-2530.txt')
# len: 14726
# ('truth-problem-874.json', 'problem-874.txt')
# len: 13032
# ('truth-problem-3081.json', 'problem-3081.txt')
# len: 16945
# ('truth-problem-2903.json', 'problem-2903.txt')
# len: 12704
# ('truth-problem-517.json', 'problem-517.txt')
# len: 19008
# ('truth-problem-852.json', 'problem-852.txt')
# len: 15795
# ('truth-problem-2538.json', 'problem-2538.txt')
# len: 10851
# ('truth-problem-3176.json', 'problem-3176.txt')
# len: 7874
# ('truth-problem-3357.json', 'problem-3357.txt')
# len: 7939
# ('truth-problem-1389.json', 'problem-1389.txt')
# len: 10450
# ('truth-problem-3362.json', 'problem-3362.txt')
# len: 6927
# ('truth-problem-26.json', 'problem-26.txt')
# len: 11298
# ('truth-problem-1464.json', 'problem-1464.txt')
# len: 14635
# ('truth-problem-2194.json', 'problem-2194.txt')
# len: 18949
# ('truth-problem-2380.json', 'problem-2380.txt')
# len: 13998
# ('truth-problem-2765.json', 'problem-2765.txt')
# len: 8965
# ('truth-problem-3368.json', 'problem-3368.txt')
# len: 7168
# ('truth-problem-3122.json', 'problem-3122.txt')
# len: 9890
# ('truth-problem-835.json', 'problem-835.txt')
# len: 14951
# ('truth-problem-2939.json', 'problem-2939.txt')
# len: 6479
# ('truth-problem-906.json', 'problem-906.txt')
# len: 8510
# ('truth-problem-801.json', 'problem-801.txt')
# len: 13663
# ('truth-problem-1960.json', 'problem-1960.txt')
# len: 7783
# ('truth-problem-2151.json', 'problem-2151.txt')
# len: 13520
# ('truth-problem-1196.json', 'problem-1196.txt')
# len: 9512
# ('truth-problem-1048.json', 'problem-1048.txt')
# len: 14888
# ('truth-problem-2906.json', 'problem-2906.txt')
# len: 12612
# 83012 83012 83012 83012 83012

# %%
df.head()
# Out:
#             problem  author_1  author_2  \
# 0  problem-1543.txt         1         1
# 1  problem-1543.txt         1         1
# 2  problem-1543.txt         1         1
# 3  problem-1543.txt         1         1
# 4  problem-1543.txt         1         2
#
#                                           para1_text  \
# 0  Full info of components of Linux Traffic Contr...
# 1  The first word in the DNS entry clearly says i...
# 2  I think you can see the point. If you are not ...
# 3  You should edit your expect script to allow fo...
# 4  You could either have a firewall rule blocking...
#
#                                           para2_text
# 0  The first word in the DNS entry clearly says i...
# 1  I think you can see the point. If you are not ...
# 2  You should edit your expect script to allow fo...
# 3  You could either have a firewall rule blocking...
# 4  You asked for "up to date", so something from ...

# %%
len(df)
# Out:
# 83012

# %%
df.to_csv(processed[selected_dataset],index=False)

# %% [markdown]
# Split text into paragraphs.Make author list according to structure and changes. Then assign paragraphs to corresponding authors. Fol

# %%
a1_list = []
a2_list = []
p1_list = []
p2_list = []
p_list = []

for i in range(0,4):#len(truth_files)):
    truth_file = truth_files[i]
    problem_file = problem_files[i]
    print((truth_file, problem_file))
    with open(data_path+problem_file) as f:
        text = f.read()
    print("len:", len(text))
    with open(data_path+truth_file) as json_file:
        data = json.load(json_file)
    structure = data['structure']
    changes = data['changes']
    count = 0
    authors = [structure[count]]
    for i in range(0,len(changes)):
        if changes[i]==0:
            authors.append(structure[count])
        else:
            count+=1
            authors.append(structure[count])
    paragraphs = text.split("\n\n")
    a1 = [authors[i-1] for i,j in enumerate(authors) if i>=1]
    a2 = [authors[i] for i,j in enumerate(authors) if i>=1]
    p1 = [paragraphs[i-1] for i,j in enumerate(paragraphs) if i>=1]
    p2 = [paragraphs[i] for i,j in enumerate(paragraphs) if i>=1]
    for author in a1:
        a1_list.append(author)
    for author in a2:
        a2_list.append(author)
    for para in p1:
        p1_list.append(para)
    for para in p2:
        p2_list.append(para)
    for author in a1: #just adding the problem files as many times as rows are present
        p_list.append(problem_file)
data = {"problem":p_list, "author_1":a1_list, "author_2":a2_list, "para1_text": p1_list, "para2_text":p2_list}
df = pd.DataFrame(data)
# Out:
# ('truth-problem-1543.json', 'problem-1543.txt')
# len: 16388
# ('truth-problem-631.json', 'problem-631.txt')
# len: 10980
# ('truth-problem-1554.json', 'problem-1554.txt')
# len: 9265
# ('truth-problem-1068.json', 'problem-1068.txt')
# len: 13175

# %%
df.head(30)
# Out:
#              problem author_1 author_2  \
# 0   problem-1543.txt       A1       A1
# 1   problem-1543.txt       A1       A2
# 2   problem-1543.txt       A2       A2
# 3   problem-1543.txt       A2       A2
# 4   problem-1543.txt       A2       A3
# 5   problem-1543.txt       A3       A3
# 6   problem-1543.txt       A3       A2
# 7   problem-1543.txt       A2       A2
# 8   problem-1543.txt       A2       A3
# 9   problem-1543.txt       A3       A3
# 10  problem-1543.txt       A3       A3
# 11  problem-1543.txt       A3       A1
# 12  problem-1543.txt       A1       A1
# 13  problem-1543.txt       A1       A1
# 14  problem-1543.txt       A1       A3
# 15  problem-1543.txt       A3       A3
# 16  problem-1543.txt       A3       A3
# 17  problem-1543.txt       A3       A2
# 18  problem-1543.txt       A2       A2
# 19  problem-1543.txt       A2       A2
# 20  problem-1543.txt       A2       A2
# 21  problem-1543.txt       A2       A3
# 22   problem-631.txt       A1       A1
# 23   problem-631.txt       A1       A1
# 24   problem-631.txt       A1       A1
# 25   problem-631.txt       A1       A1
# 26   problem-631.txt       A1       A1
# 27   problem-631.txt       A1       A1
# 28   problem-631.txt       A1       A1
# 29   problem-631.txt       A1       A1
#
#                                            para1_text  \
# 0   For your particular problem I'm not sure that ...
# 1   Perform dimensionality reduction (such as LSA ...
# 2   I read all answers, I think the simplest answe...
# 3   Best by cross validation The whole data can be...
# 4   I have an answer now for my question. I will s...
# 5   Imagine that the hyperparameter is a L2 penalt...
# 6   Self-driving cars, arms that can learn ow to p...
# 7   It depends on the expected size of neural netw...
# 8   You should use the testing set without any cha...
# 9   I'm implementing batch normalization for the f...
# 10  (The lower right plots just give the last 100 ...
# 11  Take the following tensor: $$ \left[\begin{arr...
# 12  And clearly if you wanted to selected based on...
# 13  All three approaches are valid and have their ...
# 14  Standardizing data is recommended because othe...
# 15  I like to start with an overfitting set of hyp...
# 16  When fitting neural nets and getting close to ...
# 17  N = about 7000, about 2000 input variables, 10...
# 18  When use any sampling technique ( specifically...
# 19  I am not sure if the validation set is balance...
# 20  Data Imbalance Data Imbalance + Very few numbe...
# 21  You need to understand to which of these cases...
# 22  It's not even ten lines long and yet trying to...
# 23  Adding "New" to a method name -- as in -- is j...
# 24  This is example code -- I don't know neo4j, so...
# 25  and are virtually the same method and could ea...
# 26  isn't a good class name. A class represents an...
# 27  I'd probably refactor that even more, but righ...
# 28  (This is based on my answer from yesterday, so...
# 29  Even though is only twenty-odd lines long, the...
#
#                                            para2_text
# 0   Perform dimensionality reduction (such as LSA ...
# 1   I read all answers, I think the simplest answe...
# 2   Best by cross validation The whole data can be...
# 3   I have an answer now for my question. I will s...
# 4   Imagine that the hyperparameter is a L2 penalt...
# 5   Self-driving cars, arms that can learn ow to p...
# 6   It depends on the expected size of neural netw...
# 7   You should use the testing set without any cha...
# 8   I'm implementing batch normalization for the f...
# 9   (The lower right plots just give the last 100 ...
# 10  Take the following tensor: $$ \left[\begin{arr...
# 11  And clearly if you wanted to selected based on...
# 12  All three approaches are valid and have their ...
# 13  Standardizing data is recommended because othe...
# 14  I like to start with an overfitting set of hyp...
# 15  When fitting neural nets and getting close to ...
# 16  N = about 7000, about 2000 input variables, 10...
# 17  When use any sampling technique ( specifically...
# 18  I am not sure if the validation set is balance...
# 19  Data Imbalance Data Imbalance + Very few numbe...
# 20  You need to understand to which of these cases...
# 21  Interesting question. I haven't worked with th...
# 22  Adding "New" to a method name -- as in -- is j...
# 23  This is example code -- I don't know neo4j, so...
# 24  and are virtually the same method and could ea...
# 25  isn't a good class name. A class represents an...
# 26  I'd probably refactor that even more, but righ...
# 27  (This is based on my answer from yesterday, so...
# 28  Even though is only twenty-odd lines long, the...
# 29  Don't have methods like . DB Connections shoul...

# %%
df.to_csv("/home/sukanya/PhD/Datasets/PAN SCD/pan20-style-change-detection/processed/test/narrow.csv",index=False)
